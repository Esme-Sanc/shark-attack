# %%
import pandas as pd

# %%
data_url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"

df = pd.read_excel(data_url)

# %%
df
# Out:
#              Date    Year        Type    Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
# ...           ...     ...         ...        ...                ...
# 6964          NaN     NaN         NaN        NaN                NaN
# 6965          NaN     NaN         NaN        NaN                NaN
# 6966          NaN     NaN         NaN        NaN                NaN
# 6967          NaN     NaN         NaN        NaN                NaN
# 6968          NaN     NaN         NaN        NaN                NaN
#
#                               Location  Activity                 Name  Sex  \
# ...

# %%
#Mostrar toda la info del dataframe
print("Información general del DataFrame:")
df.info()
# Out:
# Información general del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6969 entries, 0 to 6968
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6944 non-null   object
#  1   Year            6942 non-null   float64
#  2   Type            6926 non-null   object
#  3   Country         6894 non-null   object
#  4   State           6462 non-null   object
#  5   Location        6379 non-null   object
#  6   Activity        6358 non-null   object
#  7   Name            6724 non-null   object
#  8   Sex             6365 non-null   object
#  9   Age             3950 non-null   object
#  10  Injury          6909 non-null   object
#  11  Unnamed: 11     6382 non-null   object
#  12  Time            3418 non-null   object
#  13  Species         3812 non-null   object
#  14  Source          6925 non-null   object
#  15  pdf             6799 non-null   object
# ...

# %%
#2. Mostrar las primeras filas para una vista general
print("\nPrimeras filas del DataFrame:")
df.head(30)
# Out:
# Primeras filas del DataFrame:
#                     Date    Year          Type       Country  \
# 0            15 Mar 2024  2024.0    Unprovoked     AUSTRALIA
# 1            04 Mar 2024  2024.0    Unprovoked           USA
# 2            02 Mar-2024  2024.0    Unprovoked           USA
# 3            25 Feb-2024  2024.0    Unprovoked     AUSTRALIA
# 4            14 Feb-2024  2024.0    Unprovoked         INDIA
# 5            04-Feb-2024  2024.0      Provoked      TRINIDAD
# 6            29 Jan-2024  2024.0    Unprovoked     AUSTRALIA
# 7            15 Jan-2024  2024.0    Unprovoked       BAHAMAS
# 8            09-Jan-2024  2024.0    Unprovoked     AUSTRALIA
# 9            05-Jan-2024  2024.0      Provoked  SOUTH AFRICA
# 10           30 Dec-2023  2023.0    Unprovoked           USA
# 11           29 Dec-2023  2023.0    Unprovoked        MEXICO
# 12           28 Dec-2023  2023.0    Unprovoked     AUSTRALIA
# 13           25 Dec-2023  2023.0    Unprovoked     AUSTRALIA
# ...

# %%
# identificar columnas con alto porcentaje de nulos
nulos_columna_porcentaje = df.isnull().mean() * 100
nulos_columna_porcentaje
# Out:
# Date               0.358732
# Year               0.387430
# Type               0.617018
# Country            1.076195
# State              7.275075
# Location           8.466064
# Activity           8.767398
# Name               3.515569
# Sex                8.666954
# Age               43.320419
# Injury             0.860956
# Unnamed: 11        8.423016
# Time              50.954226
# Species           45.300617
# Source             0.631367
# pdf                2.439374
# href formula       2.152389
# href               2.482422
# Case Number        2.453724
# Case Number.1      2.468073
# original order     2.439374
# Unnamed: 21       99.985651
# Unnamed: 22       99.971301
# dtype: float64

# %%
# Lista de nombres de columnas a eliminar
columns_to_remove = [
    'State', 'Activity', 'Name', 'Injury',
    'Unnamed: 11', 'Time', 'Species', 'Source',
    'pdf', 'href formula', 'href', 'Case Number',
    'Case Number.1', 'original order', 'Unnamed: 21',
    'Unnamed: 22', 'Age'
]

# %%
# Eliminar las columnas del DataFrame
df_cleaned = drop_columns(df, columns_to_remove)

# %%
# Mostrar la información del DataFrame después de eliminar las columnas
print("\nDataFrame después de eliminar las columnas:")
df_cleaned.info()
# Out:
# DataFrame después de eliminar las columnas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6969 entries, 0 to 6968
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6944 non-null   object
#  1   Year      6942 non-null   float64
#  2   Type      6926 non-null   object
#  3   Country   6894 non-null   object
#  4   Location  6379 non-null   object
#  5   Sex       6365 non-null   object
#  6   Species   3812 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 381.2+ KB
